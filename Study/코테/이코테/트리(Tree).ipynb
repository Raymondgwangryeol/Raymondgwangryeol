# %% [markdown]
# ## **트리(Tree)**
# 가계도(루트 노드가 저 먼 조상님이면 단말 노드가 저 아래 어딘가의 나.. )와 같이 계층적인 구조를 표현할 때 사용할 수 있는 자료구조.

# %% [markdown]
# ![IMG_1593.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **트리 관련 용어**
# - 루트 노드(root node): 부모가 없는 최상위 노드
# - 단말 노드(leaf node): 자식이 없는 노드
# - 크기(size): 트리에 포함된 모든 노드의 개수
# - 깊이(depth): 루트 노드부터의 거리
# - 높이(height): 깊이 중 최대값
# - 차수(degree): 각 노드의 (자식 방향) 간선 개수
#
# 기본적으로 트리 크기가 N일 때, 전체 간선의 개수는 N-1개이다.
#
# <br><br>
#
# ### **이진 탐색 트리**

# %% [markdown]
# ![IMG_1594.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 이진 탐색 동작할 수 있도록 고안된 트리.
# **왼쪽 자식 노드 < 부모노드 < 오른쪽 자식 노드**
#
# ### **이진 탐색 트리 예**
# **[ 37을 찾는 과정 ]**
# 1. 루트 노드부터 방문, 탐색 진행.
#     - 현재 노드와 37을 비교. 현재 노드인 30보다 37이 더 크므로 오른쪽 방문.
#     - 30 노드의 왼쪽 부분은 확인할 필요 없음
#         - 이상적인 경우 탐색 범위가 절반 가까이 줄어듦. (O(logN))
# 2. 값이 48인 노드 확인.
#     - 현재 노드 48보다 37이 더 작으므로 왼쪽 방문.
# 3. 값이 37인 노드를 찾았으므로 찾기 종료.
#
#
# ### **트리의 순회(Tree Traversal)**
# 트리의 정보를 시각적으로 확인할 수 있음.
# - **전위 순회(pre-order traverse)**
#     - 루트를 먼저 방문
#     - **루트 → 왼쪽 → 오른쪽**
# - **중위 순회(in-order traverse)**
#     - 왼쪽 자식을 방문한 뒤에 루트 방문
#     - **왼쪽 → 루트 → 오른쪽**
# - **후위 순회(post-order travers)**
#     - 오른쪽 자식을 방문한 뒤에 루트 방문
#     - **왼쪽 → 오른쪽 → 루트**

# %% [markdown]
# ![IMG_1595.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# - **전위 순회:** A → B → D → E → C → F → G
# - **중위 순회:** D → B → E → A → F → C → G
# - **후위 순회:** D → E → B → F → G → C → A

# %%
class Node:
    def __init__(self, data, left_node, right_node):
        self.data = data
        self.left_node = left_node
        self.right_node = right_node

    # 전위 순회
    def pre_order(node):
        print(node.data, end=",")
        if node.left_node != None:
            Node.pre_order(tree[node.left_node])
        if node.right_node != None:
            Node.pre_order(tree[node.right_node])

    # 중위 순회
    def in_order(node):
        if node.left_node != None:
            Node.in_order(tree[node.left_node])
        print(node.data, end=',')
        if node.right_node != None:
            Node.in_order(tree[node.right_node])

    # 후위 순회
    def post_order(node):
        if node.left_node != None:
            Node.post_order(tree[node.left_node])
        if node.right_node != None:
            Node.post_order(tree[node.right_node])
        print(node.data, end=',')

n=int(input())
tree={}

for i in range(n):
    data,left_node, right_node = input().split()
    if left_node == 'None':
        left_node = None
    if right_node == 'None':
        right_node = None
    tree[data] = Node(data, left_node, right_node)

Node.pre_order(tree['A'])
print()
Node.in_order(tree['A'])
print()
Node.post_order(tree['A'])
# Out:
# 7
# A B C
# B D E
# C F G
# D None None
# E  None None
# F None None
# G None None
# A,B,D,E,C,F,G,
# D,B,E,A,F,C,G,
# D,E,B,F,G,C,A,
